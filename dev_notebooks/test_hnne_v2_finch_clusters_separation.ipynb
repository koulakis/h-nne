# %% [markdown]
# # Test h-nne v2

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from hnne import HNNE
from hnne_benchmarking.data import (
    load_coil20, 
    load_shuttle, 
    load_mnist,
    load_fmnist,
    load_imagenet_test,
    load_cifar_10,
    load_bbt,
    load_buffy,
    load_imagenet_train,
    load_google_news,
    load_higgs
)

# %%
DATA_PATH = Path("/home/marios/datasets/hnne_datasets")
PROJ_PATH = DATA_PATH / "projections"
cmap = "tab20"

# %% [markdown]
# ## Figure out the issue of h-nne on bbt

# %%
dataset_name = "BBT"
data, labels = load_bbt(DATA_PATH)
print(data.shape, labels.shape, pd.DataFrame(labels).groupby(0).size())
# Out:
# (199346, 2048) (199346,) 0
# 1.0    16272
# 2.0    64661
# 3.0    68286
# 4.0    18184
# 5.0    31943
# dtype: int64

# %%
hnne_v1 = HNNE(hnne_version="v1", random_state=42)
proj = hnne_v1.fit_transform(data, verbose=False)

# %%
hnne_v2 = HNNE(hnne_version="v2", random_state=42)
proj_v2 = hnne_v2.fit_transform(data, verbose=False)

# %%
_, axes = plt.subplots(1, 2, figsize=(15, 5))

plt.suptitle(f"Dataset: {dataset_name}")
ax = axes[0]
ax.set_title("HNNE")
ax.scatter(*proj.T, s=1, c=labels, cmap=cmap)

ax = axes[1]
ax.set_title("HNNE V2")
ax.scatter(*proj_v2.T, s=1, c=labels, cmap=cmap)

for ax in axes:
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])

plt.show()

# %%
_, axes = plt.subplots(1, 2, figsize=(15, 5))

level = -1
clusters_v1 = hnne_v1.hierarchy_parameters.partitions[:, level]
clusters_v2 = hnne_v2.hierarchy_parameters.partitions[:, level]

plt.suptitle(f"Dataset: {dataset_name}, Clusters level: {level}, Num clusters v1: {hnne_v1.hierarchy_parameters.partition_sizes[level]}, v2: {hnne_v2.hierarchy_parameters.partition_sizes[level]}")
ax = axes[0]
ax.set_title("HNNE")
ax.scatter(*proj.T, s=1, c=clusters_v1, cmap=cmap)

ax = axes[1]
ax.set_title("HNNE V2")
ax.scatter(*proj_v2.T, s=1, c=clusters_v2, cmap=cmap)

for ax in axes:
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])

plt.show()

# %% [markdown]
# ## Create h-nne visualizations for all datasets

# %% [markdown]
# ### COIL-20

# %%
dataset_name = "COIL-20"
data, labels = load_coil20(DATA_PATH)
print(data.shape, labels.shape)
# Out:
# (1440, 16384) (1440,)

# %%
hnne_v1 = HNNE(hnne_version="v1", random_state=42)
proj = hnne_v1.fit_transform(data, verbose=False)

# %%
hnne_v2 = HNNE(hnne_version="v2", random_state=42)
proj_v2 = hnne_v2.fit_transform(data, verbose=False)

# %%
_, axes = plt.subplots(1, 2, figsize=(15, 5))

plt.suptitle(f"Dataset: {dataset_name}")
ax = axes[0]
ax.set_title("HNNE")
ax.scatter(*proj.T, s=1, c=labels, cmap=cmap)

ax = axes[1]
ax.set_title("HNNE V2")
ax.scatter(*proj_v2.T, s=1, c=labels, cmap=cmap)

for ax in axes:
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])

plt.show()

# %%
_, axes = plt.subplots(1, 2, figsize=(15, 5))

level = -1
clusters_v1 = hnne_v1.hierarchy_parameters.partitions[:, level]
clusters_v2 = hnne_v2.hierarchy_parameters.partitions[:, level]

plt.suptitle(f"Dataset: {dataset_name}, Clusters level: {level}, Num clusters v1: {hnne_v1.hierarchy_parameters.partition_sizes[level]}, v2: {hnne_v2.hierarchy_parameters.partition_sizes[level]}")
ax = axes[0]
ax.set_title("HNNE")
ax.scatter(*proj.T, s=1, c=clusters_v1, cmap=cmap)

ax = axes[1]
ax.set_title("HNNE V2")
ax.scatter(*proj_v2.T, s=1, c=clusters_v2, cmap=cmap)

for ax in axes:
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])

plt.show()

# %% [markdown]
# ### Shuttle

# %%
dataset_name = "Shuttle"
data, labels = load_shuttle(DATA_PATH)
print(data.shape, labels.shape)
# Out:
# (58000, 9) (58000,)

# %%
hnne_v1 = HNNE(hnne_version="v1", random_state=42)
proj = hnne_v1.fit_transform(data, verbose=False)

# %%
hnne_v2 = HNNE(hnne_version="v2", random_state=42)
proj_v2 = hnne_v2.fit_transform(data, verbose=False)

# %%
_, axes = plt.subplots(1, 2, figsize=(15, 5))

plt.suptitle(f"Dataset: {dataset_name}")
ax = axes[0]
ax.set_title("HNNE")
ax.scatter(*proj.T, s=1, c=labels, cmap=cmap)

ax = axes[1]
ax.set_title("HNNE V2")
ax.scatter(*proj_v2.T, s=1, c=labels, cmap=cmap)

for ax in axes:
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])

plt.show()

# %%
_, axes = plt.subplots(1, 2, figsize=(15, 5))

level = -1
clusters_v1 = hnne_v1.hierarchy_parameters.partitions[:, level]
clusters_v2 = hnne_v2.hierarchy_parameters.partitions[:, level]

plt.suptitle(f"Dataset: {dataset_name}, Clusters level: {level}, Num clusters v1: {hnne_v1.hierarchy_parameters.partition_sizes[level]}, v2: {hnne_v2.hierarchy_parameters.partition_sizes[level]}")
ax = axes[0]
ax.set_title("HNNE")
ax.scatter(*proj.T, s=1, c=clusters_v1, cmap=cmap)

ax = axes[1]
ax.set_title("HNNE V2")
ax.scatter(*proj_v2.T, s=1, c=clusters_v2, cmap=cmap)

for ax in axes:
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])

plt.show()

# %% [markdown]
# ### MNIST

# %%
dataset_name = "MNIST"
data, labels = load_mnist(DATA_PATH)
print(data.shape, labels.shape)
# Out:
# (70000, 784) (70000,)

# %%
hnne_v1 = HNNE(hnne_version="v1", random_state=42)
proj = hnne_v1.fit_transform(data, verbose=False)

# %%
hnne_v2 = HNNE(hnne_version="v2", random_state=42)
proj_v2 = hnne_v2.fit_transform(data, verbose=False)

# %%
_, axes = plt.subplots(1, 2, figsize=(15, 5))

plt.suptitle(f"Dataset: {dataset_name}")
ax = axes[0]
ax.set_title("HNNE")
ax.scatter(*proj.T, s=1, c=labels, cmap=cmap)

ax = axes[1]
ax.set_title("HNNE V2")
ax.scatter(*proj_v2.T, s=1, c=labels, cmap=cmap)

for ax in axes:
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])

plt.show()

# %%
_, axes = plt.subplots(1, 2, figsize=(15, 5))

level = -1
clusters_v1 = hnne_v1.hierarchy_parameters.partitions[:, level]
clusters_v2 = hnne_v2.hierarchy_parameters.partitions[:, level]

plt.suptitle(f"Dataset: {dataset_name}, Clusters level: {level}, Num clusters v1: {hnne_v1.hierarchy_parameters.partition_sizes[level]}, v2: {hnne_v2.hierarchy_parameters.partition_sizes[level]}")
ax = axes[0]
ax.set_title("HNNE")
ax.scatter(*proj.T, s=1, c=clusters_v1, cmap=cmap)

ax = axes[1]
ax.set_title("HNNE V2")
ax.scatter(*proj_v2.T, s=1, c=clusters_v2, cmap=cmap)

for ax in axes:
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])

plt.show()

# %% [markdown]
# ### FMNIST

# %%
dataset_name = "FMNIST"
data, labels = load_fmnist(DATA_PATH)
print(data.shape, labels.shape)
# Out:
# (70000, 784) (70000,)

# %%
hnne_v1 = HNNE(hnne_version="v1", random_state=42)
proj = hnne_v1.fit_transform(data, verbose=False)

# %%
hnne_v2 = HNNE(hnne_version="v2", random_state=42)
proj_v2 = hnne_v2.fit_transform(data, verbose=False)

# %%
_, axes = plt.subplots(1, 2, figsize=(15, 5))

plt.suptitle(f"Dataset: {dataset_name}")
ax = axes[0]
ax.set_title("HNNE")
ax.scatter(*proj.T, s=1, c=labels, cmap=cmap)

ax = axes[1]
ax.set_title("HNNE V2")
ax.scatter(*proj_v2.T, s=1, c=labels, cmap=cmap)

for ax in axes:
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])

plt.show()

# %%
_, axes = plt.subplots(1, 2, figsize=(15, 5))

level = -1
clusters_v1 = hnne_v1.hierarchy_parameters.partitions[:, level]
clusters_v2 = hnne_v2.hierarchy_parameters.partitions[:, level]

plt.suptitle(f"Dataset: {dataset_name}, Clusters level: {level}, Num clusters v1: {hnne_v1.hierarchy_parameters.partition_sizes[level]}, v2: {hnne_v2.hierarchy_parameters.partition_sizes[level]}")
ax = axes[0]
ax.set_title("HNNE")
ax.scatter(*proj.T, s=1, c=clusters_v1, cmap=cmap)

ax = axes[1]
ax.set_title("HNNE V2")
ax.scatter(*proj_v2.T, s=1, c=clusters_v2, cmap=cmap)

for ax in axes:
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])

plt.show()

# %% [markdown]
# ### ImageNet Test

# %%
dataset_name = "ImageNet Test"
data, labels = load_imagenet_test(DATA_PATH)
print(data.shape, labels.shape)
# Out:
# (50000, 2048) (50000,)

# %%
hnne_v1 = HNNE(hnne_version="v1", random_state=42)
proj = hnne_v1.fit_transform(data, verbose=False)

# %%
hnne_v2 = HNNE(hnne_version="v2", random_state=42)
proj_v2 = hnne_v2.fit_transform(data, verbose=False)

# %%
_, axes = plt.subplots(1, 2, figsize=(15, 5))

plt.suptitle(f"Dataset: {dataset_name}")
ax = axes[0]
ax.set_title("HNNE")
ax.scatter(*proj.T, s=1, c=labels, cmap=cmap)

ax = axes[1]
ax.set_title("HNNE V2")
ax.scatter(*proj_v2.T, s=1, c=labels, cmap=cmap)

for ax in axes:
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])

plt.show()

# %%
_, axes = plt.subplots(1, 2, figsize=(15, 5))

level = -1
clusters_v1 = hnne_v1.hierarchy_parameters.partitions[:, level]
clusters_v2 = hnne_v2.hierarchy_parameters.partitions[:, level]

plt.suptitle(f"Dataset: {dataset_name}, Clusters level: {level}, Num clusters v1: {hnne_v1.hierarchy_parameters.partition_sizes[level]}, v2: {hnne_v2.hierarchy_parameters.partition_sizes[level]}")
ax = axes[0]
ax.set_title("HNNE")
ax.scatter(*proj.T, s=1, c=clusters_v1, cmap=cmap)

ax = axes[1]
ax.set_title("HNNE V2")
ax.scatter(*proj_v2.T, s=1, c=clusters_v2, cmap=cmap)

for ax in axes:
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])

plt.show()

# %% [markdown]
# ### CIFAR-10

# %%
dataset_name = "CIFAR-10"
data, labels = load_cifar_10(DATA_PATH)
print(data.shape, labels.shape)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# (60000, 3072) (60000,)

# %%
hnne_v1 = HNNE(hnne_version="v1", random_state=42)
proj = hnne_v1.fit_transform(data, verbose=False)

# %%
hnne_v2 = HNNE(hnne_version="v2", random_state=42)
proj_v2 = hnne_v2.fit_transform(data, verbose=False)

# %%
_, axes = plt.subplots(1, 2, figsize=(15, 5))

plt.suptitle(f"Dataset: {dataset_name}")
ax = axes[0]
ax.set_title("HNNE")
ax.scatter(*proj.T, s=1, c=labels, cmap=cmap)

ax = axes[1]
ax.set_title("HNNE V2")
ax.scatter(*proj_v2.T, s=1, c=labels, cmap=cmap)

for ax in axes:
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])

plt.show()

# %%
_, axes = plt.subplots(1, 2, figsize=(15, 5))

level = -1
clusters_v1 = hnne_v1.hierarchy_parameters.partitions[:, level]
clusters_v2 = hnne_v2.hierarchy_parameters.partitions[:, level]

plt.suptitle(f"Dataset: {dataset_name}, Clusters level: {level}, Num clusters v1: {hnne_v1.hierarchy_parameters.partition_sizes[level]}, v2: {hnne_v2.hierarchy_parameters.partition_sizes[level]}")
ax = axes[0]
ax.set_title("HNNE")
ax.scatter(*proj.T, s=1, c=clusters_v1, cmap=cmap)

ax = axes[1]
ax.set_title("HNNE V2")
ax.scatter(*proj_v2.T, s=1, c=clusters_v2, cmap=cmap)

for ax in axes:
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])

plt.show()

# %% [markdown]
# ### Buffy

# %%
dataset_name = "Buffy"
data, labels = load_buffy(DATA_PATH)
print(data.shape, labels.shape)
# Out:
# (206254, 2048) (206254,)

# %%
hnne_v1 = HNNE(hnne_version="v1", random_state=42)
proj = hnne_v1.fit_transform(data, verbose=False)

# %%
hnne_v2 = HNNE(hnne_version="v2", random_state=42)
proj_v2 = hnne_v2.fit_transform(data, verbose=False)

# %%
_, axes = plt.subplots(1, 2, figsize=(15, 5))

plt.suptitle(f"Dataset: {dataset_name}")
ax = axes[0]
ax.set_title("HNNE")
ax.scatter(*proj.T, s=1, c=labels, cmap=cmap)

ax = axes[1]
ax.set_title("HNNE V2")
ax.scatter(*proj_v2.T, s=1, c=labels, cmap=cmap)

for ax in axes:
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])

plt.show()

# %%
_, axes = plt.subplots(1, 2, figsize=(15, 5))

level = -1
clusters_v1 = hnne_v1.hierarchy_parameters.partitions[:, level]
clusters_v2 = hnne_v2.hierarchy_parameters.partitions[:, level]

plt.suptitle(f"Dataset: {dataset_name}, Clusters level: {level}, Num clusters v1: {hnne_v1.hierarchy_parameters.partition_sizes[level]}, v2: {hnne_v2.hierarchy_parameters.partition_sizes[level]}")
ax = axes[0]
ax.set_title("HNNE")
ax.scatter(*proj.T, s=1, c=clusters_v1, cmap=cmap)

ax = axes[1]
ax.set_title("HNNE V2")
ax.scatter(*proj_v2.T, s=1, c=clusters_v2, cmap=cmap)

for ax in axes:
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])

plt.show()

# %% [markdown]
# ### ImageNet Train

# %%
dataset_name = "ImageNet Train"
data, labels = load_imagenet_train(DATA_PATH)
print(data.shape, labels.shape)
# Out:
# (1281167, 2048) (1281167,)

# %%
# %%time
hnne_v1 = HNNE(hnne_version="v1")
proj = hnne_v1.fit_transform(data, verbose=False)

# %%
# %%time
hnne_v2 = HNNE(hnne_version="v2")
proj_v2 = hnne_v2.fit_transform(data, verbose=False)

# %%
_, axes = plt.subplots(1, 2, figsize=(15, 5))

plt.suptitle(f"Dataset: {dataset_name}")
ax = axes[0]
ax.set_title("HNNE")
ax.scatter(*proj.T, s=1, c=labels, cmap=cmap)

ax = axes[1]
ax.set_title("HNNE V2")
ax.scatter(*proj_v2.T, s=1, c=labels, cmap=cmap)

for ax in axes:
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])

plt.show()

# %%
_, axes = plt.subplots(1, 2, figsize=(15, 5))

level_v1 = -1
level_v2 = -1
clusters_v1 = hnne_v1.hierarchy_parameters.partitions[:, level_v1]
clusters_v2 = hnne_v2.hierarchy_parameters.partitions[:, level_v2]

plt.suptitle(f"Dataset: {dataset_name}, Clusters level: {level}, Num clusters v1: {hnne_v1.hierarchy_parameters.partition_sizes[level_v1]}, v2: {hnne_v2.hierarchy_parameters.partition_sizes[level_v2]}")
ax = axes[0]
ax.set_title("HNNE")
ax.scatter(*proj.T, s=1, c=clusters_v1, cmap=cmap)

ax = axes[1]
ax.set_title("HNNE V2")
ax.scatter(*proj_v2.T, s=1, c=clusters_v2, cmap=cmap)

for ax in axes:
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])

plt.show()

# %% [markdown]
# ### Higgs

# %%
dataset_name = "Higgs"
data, labels = load_higgs(DATA_PATH)
print(data.shape, labels.shape)
# Out:
# (11000000, 28) (11000000,)

# %%
# %%time
hnne_v1 = HNNE(hnne_version="v1")
proj = hnne_v1.fit_transform(data, verbose=False)

# %%
# %%time
hnne_v2 = HNNE(hnne_version="v2")
proj_v2 = hnne_v2.fit_transform(data, verbose=False)

# %%
_, axes = plt.subplots(1, 2, figsize=(15, 5))

plt.suptitle(f"Dataset: {dataset_name}")
ax = axes[0]
ax.set_title("HNNE")
ax.scatter(*proj.T, s=1, c=labels, cmap=cmap)

ax = axes[1]
ax.set_title("HNNE V2")
ax.scatter(*proj_v2.T, s=1, c=labels, cmap=cmap)

for ax in axes:
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])

plt.show()

# %%
_, axes = plt.subplots(1, 2, figsize=(15, 5))

level_v1 = -1
level_v2 = -1
clusters_v1 = hnne_v1.hierarchy_parameters.partitions[:, level_v1]
clusters_v2 = hnne_v2.hierarchy_parameters.partitions[:, level_v2]

plt.suptitle(f"Dataset: {dataset_name}, Clusters level: {level}, Num clusters v1: {hnne_v1.hierarchy_parameters.partition_sizes[level_v1]}, v2: {hnne_v2.hierarchy_parameters.partition_sizes[level_v2]}")
ax = axes[0]
ax.set_title("HNNE")
ax.scatter(*proj.T, s=1, c=clusters_v1, cmap=cmap)

ax = axes[1]
ax.set_title("HNNE V2")
ax.scatter(*proj_v2.T, s=1, c=clusters_v2, cmap=cmap)

for ax in axes:
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])

plt.show()

# %% [markdown]
# ### Google News

# %%
dataset_name = "Google News"
data, labels = load_google_news(DATA_PATH)
print(data.shape, labels.shape)
# Out:
# (3000000, 300) (3000000,)

# %%
hnne_v1 = HNNE(hnne_version="v1", random_state=42)
proj = hnne_v1.fit_transform(data, verbose=False)

# %%
hnne_v2 = HNNE(hnne_version="v2", random_state=42)
proj_v2 = hnne_v2.fit_transform(data, verbose=False)

# %%
_, axes = plt.subplots(1, 2, figsize=(15, 5))

level = -1
clusters_v1 = hnne_v1.hierarchy_parameters.partitions[:, level]
clusters_v2 = hnne_v2.hierarchy_parameters.partitions[:, level]

plt.suptitle(f"Dataset: {dataset_name}, Clusters level: {level}, Num clusters v1: {hnne_v1.hierarchy_parameters.partition_sizes[level]}, v2: {hnne_v2.hierarchy_parameters.partition_sizes[level]}")
ax = axes[0]
ax.set_title("HNNE")
ax.scatter(*proj.T, s=1, c=clusters_v1, cmap=cmap)

ax = axes[1]
ax.set_title("HNNE V2")
ax.scatter(*proj_v2.T, s=1, c=clusters_v2, cmap=cmap)

for ax in axes:
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])

plt.show()
