# %% [markdown]
# # Test h-nne v2

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from hnne import HNNE as HNNE_ORIG
from hnne_v2 import HNNE as HNNE_V2
from benchmarking.data import (
    load_coil20, 
    load_shuttle, 
    load_mnist,
    load_fmnist,
    load_imagenet_test,
    load_cifar_10,
    load_bbt,
    load_buffy,
    load_imagenet_train,
    load_google_news,
    load_higgs
)

# %%
DATA_PATH = Path("/home/marios/datasets/hnne_datasets")
PROJ_PATH = DATA_PATH / "projections"
cmap = "tab20"

# %% [markdown]
# ## Figure out the issue of h-nne on bbt

# %%
dataset_name = "BBT"
data, labels = load_bbt(DATA_PATH)
print(data.shape, labels.shape, pd.DataFrame(labels).groupby(0).size())
# Out:
# (199346, 2048) (199346,) 0
# 1.0    16272
# 2.0    64661
# 3.0    68286
# 4.0    18184
# 5.0    31943
# dtype: int64

# %%
proj = HNNE_ORIG().fit_transform(data, verbose=False)

# %%
proj_new = HNNE_V2(hnne_v2=False).fit_transform(data, verbose=False)

# %%
proj_v2 = HNNE_V2(hnne_v2=True).fit_transform(data, verbose=False)

# %%
_, axes = plt.subplots(1, 3, figsize=(20, 5))

plt.suptitle(f"Dataset: {dataset_name}")
ax = axes[0]
ax.set_title("HNNE")
ax.scatter(*proj.T, s=1, c=labels, cmap=cmap)

ax = axes[1]
ax.set_title("HNNE NEW")
ax.scatter(*proj_new.T, s=1, c=labels, cmap=cmap)

ax = axes[2]
ax.set_title("HNNE V2")
ax.scatter(*proj_v2.T, s=1, c=labels, cmap=cmap)

for ax in axes:
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])

plt.show()

# %%
np.savez(
    PROJ_PATH / f"{dataset_name}.npz", 
    proj=proj, 
    proj_new=proj_new, 
    proj_v2=proj_v2, 
    labels=labels
)

# %% [markdown]
# ## Create h-nne visualizations for all datasets

# %% [markdown]
# ### COIL-20

# %%
dataset_name = "COIL-20"
data, labels = load_coil20(DATA_PATH)
print(data.shape, labels.shape)
# Out:
# (1440, 16384) (1440,)

# %%
proj = HNNE_ORIG().fit_transform(data, verbose=False)

# %%
proj_new = HNNE_V2(hnne_v2=False).fit_transform(data, verbose=False)

# %%
proj_v2 = HNNE_V2(hnne_v2=True).fit_transform(data, verbose=False)

# %%
_, axes = plt.subplots(1, 3, figsize=(20, 5))

plt.suptitle(f"Dataset: {dataset_name}")
ax = axes[0]
ax.set_title("HNNE")
ax.scatter(*proj.T, s=1, c=labels, cmap=cmap)

ax = axes[1]
ax.set_title("HNNE NEW")
ax.scatter(*proj_new.T, s=1, c=labels, cmap=cmap)

ax = axes[2]
ax.set_title("HNNE V2")
ax.scatter(*proj_v2.T, s=1, c=labels, cmap=cmap)

for ax in axes:
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])

plt.show()

# %%
np.savez(
    PROJ_PATH / f"{dataset_name}.npz", 
    proj=proj, 
    proj_new=proj_new, 
    proj_v2=proj_v2, 
    labels=labels
)

# %% [markdown]
# ### Shuttle

# %%
dataset_name = "Shuttle"
data, labels = load_shuttle(DATA_PATH)
print(data.shape, labels.shape)
# Out:
# (58000, 9) (58000,)

# %%
proj = HNNE_ORIG().fit_transform(data, verbose=False)

# %%
proj_new = HNNE_V2(hnne_v2=False).fit_transform(data, verbose=False)

# %%
proj_v2 = HNNE_V2(hnne_v2=True).fit_transform(data, verbose=False)

# %%
_, axes = plt.subplots(1, 3, figsize=(20, 5))

plt.suptitle(f"Dataset: {dataset_name}")
ax = axes[0]
ax.set_title("HNNE")
ax.scatter(*proj.T, s=1, c=labels, cmap=cmap)

ax = axes[1]
ax.set_title("HNNE NEW")
ax.scatter(*proj_new.T, s=1, c=labels, cmap=cmap)

ax = axes[2]
ax.set_title("HNNE V2")
ax.scatter(*proj_v2.T, s=1, c=labels, cmap=cmap)

for ax in axes:
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])

plt.show()

# %%
np.savez(
    PROJ_PATH / f"{dataset_name}.npz", 
    proj=proj, 
    proj_new=proj_new, 
    proj_v2=proj_v2, 
    labels=labels
)

# %% [markdown]
# ### MNIST

# %%
dataset_name = "MNIST"
data, labels = load_mnist(DATA_PATH)
print(data.shape, labels.shape)
# Out:
# (70000, 784) (70000,)

# %%
proj = HNNE_ORIG().fit_transform(data, verbose=False)

# %%
proj_new = HNNE_V2(hnne_v2=False).fit_transform(data, verbose=False)

# %%
proj_v2 = HNNE_V2(hnne_v2=True).fit_transform(data, verbose=False)

# %%
_, axes = plt.subplots(1, 3, figsize=(20, 5))

plt.suptitle(f"Dataset: {dataset_name}")
ax = axes[0]
ax.set_title("HNNE")
ax.scatter(*proj.T, s=1, c=labels, cmap=cmap)

ax = axes[1]
ax.set_title("HNNE NEW")
ax.scatter(*proj_new.T, s=1, c=labels, cmap=cmap)

ax = axes[2]
ax.set_title("HNNE V2")
ax.scatter(*proj_v2.T, s=1, c=labels, cmap=cmap)

for ax in axes:
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])

plt.show()

# %%
np.savez(
    PROJ_PATH / f"{dataset_name}.npz", 
    proj=proj, 
    proj_new=proj_new, 
    proj_v2=proj_v2, 
    labels=labels
)

# %% [markdown]
# ### FMNIST

# %%
dataset_name = "FMNIST"
data, labels = load_fmnist(DATA_PATH)
print(data.shape, labels.shape)
# Out:
# (70000, 784) (70000,)

# %%
proj = HNNE_ORIG().fit_transform(data, verbose=False)

# %%
proj_new = HNNE_V2(hnne_v2=False).fit_transform(data, verbose=False)

# %%
proj_v2 = HNNE_V2(hnne_v2=True).fit_transform(data, verbose=False)

# %%
_, axes = plt.subplots(1, 3, figsize=(20, 5))

plt.suptitle(f"Dataset: {dataset_name}")
ax = axes[0]
ax.set_title("HNNE")
ax.scatter(*proj.T, s=1, c=labels, cmap=cmap)

ax = axes[1]
ax.set_title("HNNE NEW")
ax.scatter(*proj_new.T, s=1, c=labels, cmap=cmap)

ax = axes[2]
ax.set_title("HNNE V2")
ax.scatter(*proj_v2.T, s=1, c=labels, cmap=cmap)

for ax in axes:
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])

plt.show()

# %%
np.savez(
    PROJ_PATH / f"{dataset_name}.npz", 
    proj=proj, 
    proj_new=proj_new, 
    proj_v2=proj_v2, 
    labels=labels
)

# %% [markdown]
# ### ImageNet Test

# %%
dataset_name = "ImageNet Test"
data, labels = load_imagenet_test(DATA_PATH)
print(data.shape, labels.shape)
# Out:
# (50000, 2048) (50000,)

# %%
proj = HNNE_ORIG().fit_transform(data, verbose=False)

# %%
proj_new = HNNE_V2(hnne_v2=False).fit_transform(data, verbose=False)

# %%
proj_v2 = HNNE_V2(hnne_v2=True).fit_transform(data, verbose=False)

# %%
_, axes = plt.subplots(1, 3, figsize=(20, 5))

plt.suptitle(f"Dataset: {dataset_name}")
ax = axes[0]
ax.set_title("HNNE")
ax.scatter(*proj.T, s=1, c=labels, cmap=cmap)

ax = axes[1]
ax.set_title("HNNE NEW")
ax.scatter(*proj_new.T, s=1, c=labels, cmap=cmap)

ax = axes[2]
ax.set_title("HNNE V2")
ax.scatter(*proj_v2.T, s=1, c=labels, cmap=cmap)

for ax in axes:
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])

plt.show()

# %%
np.savez(
    PROJ_PATH / f"{dataset_name}.npz", 
    proj=proj, 
    proj_new=proj_new, 
    proj_v2=proj_v2, 
    labels=labels
)

# %% [markdown]
# ### CIFAR-10

# %%
dataset_name = "CIFAR-10"
data, labels = load_cifar_10(DATA_PATH)
print(data.shape, labels.shape)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# (60000, 3072) (60000,)

# %%
proj = HNNE_ORIG().fit_transform(data, verbose=False)

# %%
proj_new = HNNE_V2(hnne_v2=False).fit_transform(data, verbose=False)

# %%
proj_v2 = HNNE_V2(hnne_v2=True).fit_transform(data, verbose=False)

# %%
_, axes = plt.subplots(1, 3, figsize=(20, 5))

plt.suptitle(f"Dataset: {dataset_name}")
ax = axes[0]
ax.set_title("HNNE")
ax.scatter(*proj.T, s=1, c=labels, cmap=cmap)

ax = axes[1]
ax.set_title("HNNE NEW")
ax.scatter(*proj_new.T, s=1, c=labels, cmap=cmap)

ax = axes[2]
ax.set_title("HNNE V2")
ax.scatter(*proj_v2.T, s=1, c=labels, cmap=cmap)

for ax in axes:
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])

plt.show()

# %%
np.savez(
    PROJ_PATH / f"{dataset_name}.npz", 
    proj=proj, 
    proj_new=proj_new, 
    proj_v2=proj_v2, 
    labels=labels
)

# %% [markdown]
# ### Buffy

# %%
dataset_name = "Buffy"
data, labels = load_buffy(DATA_PATH)
print(data.shape, labels.shape)
# Out:
# (206254, 2048) (206254,)

# %%
proj = HNNE_ORIG().fit_transform(data, verbose=False)

# %%
proj_new = HNNE_V2(hnne_v2=False).fit_transform(data, verbose=False)

# %%
proj_v2 = HNNE_V2(hnne_v2=True).fit_transform(data, verbose=False)
# Out:
# [INFO]: The required start_cluster_view is smaller than the default top level of used FINCH hierarchy i.e. 11 clusters. Please set this using prefered_num_clust when initializing HNNE (prefered_num_clust=None).

# %%
_, axes = plt.subplots(1, 3, figsize=(20, 5))

plt.suptitle(f"Dataset: {dataset_name}")
ax = axes[0]
ax.set_title("HNNE")
ax.scatter(*proj.T, s=1, c=labels, cmap=cmap)

ax = axes[1]
ax.set_title("HNNE NEW")
ax.scatter(*proj_new.T, s=1, c=labels, cmap=cmap)

ax = axes[2]
ax.set_title("HNNE V2")
ax.scatter(*proj_v2.T, s=1, c=labels, cmap=cmap)

for ax in axes:
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])

plt.show()

# %%
np.savez(
    PROJ_PATH / f"{dataset_name}.npz", 
    proj=proj, 
    proj_new=proj_new, 
    proj_v2=proj_v2, 
    labels=labels
)

# %%
np.savez(
    PROJ_PATH / f"{dataset_name}.npz", 
    proj=proj, 
    proj_new=proj_new, 
    proj_v2=proj_v2, 
    labels=labels
)

# %% [markdown]
# ### ImageNet Train

# %%
dataset_name = "ImageNet Train"
data, labels = load_imagenet_train(DATA_PATH)
print(data.shape, labels.shape)
# Out:
# (1281167, 2048) (1281167,)

# %%
proj = HNNE_ORIG().fit_transform(data, verbose=True)
# Out:
# Building h-NNE hierarchy using FINCH...
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Mon Oct 13 21:49:08 2025 Building RP forest with 32 trees
# Mon Oct 13 21:51:23 2025 NN descent for 20 iterations
# 	 1  /  20
# 	 2  /  20
# 	 3  /  20
# 	 4  /  20
# 	Stopping threshold met -- exiting after 4 iterations
# Step PyNNDescent done ...
# Level 0: 172140 clusters
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Mon Oct 13 21:51:57 2025 Building RP forest with 25 trees
# Mon Oct 13 21:52:08 2025 NN descent for 17 iterations
# 	 1  /  17
# 	 2  /  17
# 	 3  /  17
# 	 4  /  17
# 	Stopping threshold met -- exiting after 4 iterations
# Step PyNNDescent done ...
# Level 1: 20150 clusters
# Level 2: 4773 clusters
# Level 3: 838 clusters
# Level 4: 177 clusters
# Level 5: 30 clusters
# Level 6: 7 clusters
# Level 7: 2 clusters
# Removing 1 levels from the top to start with a levelof size at least 3.
# Projecting to 2 dimensions...
# ...

# %%
proj_new = HNNE_V2(hnne_v2=False).fit_transform(data, verbose=True)
# Out:
# Building h-NNE hierarchy using FINCH...
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Mon Oct 13 21:54:59 2025 Building RP forest with 32 trees
# Mon Oct 13 21:57:13 2025 NN descent for 20 iterations
# 	 1  /  20
# 	 2  /  20
# 	 3  /  20
# 	 4  /  20
# 	Stopping threshold met -- exiting after 4 iterations
# Step PyNNDescent done ...
# Level 0: 172242 clusters
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Mon Oct 13 21:57:47 2025 Building RP forest with 25 trees
# Mon Oct 13 21:57:57 2025 NN descent for 17 iterations
# 	 1  /  17
# 	 2  /  17
# 	 3  /  17
# 	 4  /  17
# 	Stopping threshold met -- exiting after 4 iterations
# Step PyNNDescent done ...
# Level 1: 20139 clusters
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Mon Oct 13 21:58:16 2025 Building RP forest with 17 trees
# Mon Oct 13 21:58:17 2025 NN descent for 14 iterations
# 	 1  /  14
# 	 2  /  14
# 	 3  /  14
# 	 4  /  14
# ...

# %%
proj_v2 = HNNE_V2(hnne_v2=True).fit_transform(data, verbose=True)
# Out:
# Building h-NNE hierarchy using FINCH...
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Mon Oct 13 22:00:37 2025 Building RP forest with 32 trees
# Mon Oct 13 22:02:51 2025 NN descent for 20 iterations
# 	 1  /  20
# 	 2  /  20
# 	 3  /  20
# 	 4  /  20
# 	Stopping threshold met -- exiting after 4 iterations
# Step PyNNDescent done ...
# Level 0: 171925 clusters
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Mon Oct 13 22:03:25 2025 Building RP forest with 25 trees
# Mon Oct 13 22:03:36 2025 NN descent for 17 iterations
# 	 1  /  17
# 	 2  /  17
# 	 3  /  17
# 	 4  /  17
# 	Stopping threshold met -- exiting after 4 iterations
# Step PyNNDescent done ...
# Level 1: 19981 clusters
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Mon Oct 13 22:03:55 2025 Building RP forest with 17 trees
# Mon Oct 13 22:03:55 2025 NN descent for 14 iterations
# 	 1  /  14
# 	 2  /  14
# 	 3  /  14
# 	 4  /  14
# ...

# %%
_, axes = plt.subplots(1, 3, figsize=(20, 5))

N = 100_000
idx = np.random.choice(data.shape[0], size=N, replace=False)

plt.suptitle(f"Dataset: {dataset_name}")
ax = axes[0]
ax.set_title("HNNE")
ax.scatter(*proj[idx].T, s=1, c=labels[idx], cmap=cmap)

ax = axes[1]
ax.set_title("HNNE NEW")
ax.scatter(*proj_new[idx].T, s=1, c=labels[idx], cmap=cmap)

ax = axes[2]
ax.set_title("HNNE V2")
ax.scatter(*proj_v2[idx].T, s=1, c=labels[idx], cmap=cmap)

for ax in axes:
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])

plt.show()

# %%
np.savez(
    PROJ_PATH / f"{dataset_name}.npz", 
    proj=proj, 
    proj_new=proj_new, 
    proj_v2=proj_v2, 
    labels=labels
)

# %% [markdown]
# #### Zoom into imagenet and check projections

# %%
_, axes = plt.subplots(1, 3, figsize=(20, 5))

idx = labels == 5

plt.suptitle(f"Dataset: {dataset_name}")
ax = axes[0]
ax.set_title("HNNE")
ax.scatter(*proj[idx].T, s=1, c=labels[idx], cmap=cmap)

ax = axes[1]
ax.set_title("HNNE NEW")
ax.scatter(*proj_new[idx].T, s=1, c=labels[idx], cmap=cmap)

ax = axes[2]
ax.set_title("HNNE V2")
ax.scatter(*proj_v2[idx].T, s=1, c=labels[idx], cmap=cmap)

for ax in axes:
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])

plt.show()

# %% [markdown]
# ### Higgs

# %%
dataset_name = "Higgs"
data, labels = load_higgs(DATA_PATH)
print(data.shape, labels.shape)
# Out:
# (11000000, 28) (11000000,)

# %%
proj = HNNE_ORIG().fit_transform(data, verbose=True)
# Out:
# Building h-NNE hierarchy using FINCH...
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Mon Oct 13 22:07:17 2025 Building RP forest with 32 trees
# Mon Oct 13 22:07:45 2025 NN descent for 23 iterations
# 	 1  /  23
# 	 2  /  23
# 	 3  /  23
# 	 4  /  23
# 	Stopping threshold met -- exiting after 4 iterations
# Step PyNNDescent done ...
# Level 0: 2573525 clusters
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Mon Oct 13 22:09:22 2025 Building RP forest with 32 trees
# Mon Oct 13 22:09:27 2025 NN descent for 21 iterations
# 	 1  /  21
# 	 2  /  21
# 	 3  /  21
# 	 4  /  21
# 	Stopping threshold met -- exiting after 4 iterations
# Step PyNNDescent done ...
# Level 1: 723843 clusters
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Mon Oct 13 22:09:52 2025 Building RP forest with 32 trees
# Mon Oct 13 22:09:53 2025 NN descent for 19 iterations
# 	 1  /  19
# 	 2  /  19
# 	 3  /  19
# ...

# %%
proj_new = HNNE_V2(hnne_v2=False).fit_transform(data, verbose=True)
# Out:
# Building h-NNE hierarchy using FINCH...
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Mon Oct 13 22:13:48 2025 Building RP forest with 32 trees
# Mon Oct 13 22:14:14 2025 NN descent for 23 iterations
# 	 1  /  23
# 	 2  /  23
# 	 3  /  23
# 	 4  /  23
# 	Stopping threshold met -- exiting after 4 iterations
# Step PyNNDescent done ...
# Level 0: 2573685 clusters
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Mon Oct 13 22:15:57 2025 Building RP forest with 32 trees
# Mon Oct 13 22:16:03 2025 NN descent for 21 iterations
# 	 1  /  21
# 	 2  /  21
# 	 3  /  21
# 	Stopping threshold met -- exiting after 3 iterations
# Step PyNNDescent done ...
# Level 1: 724706 clusters
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Mon Oct 13 22:16:27 2025 Building RP forest with 32 trees
# Mon Oct 13 22:16:28 2025 NN descent for 19 iterations
# 	 1  /  19
# 	 2  /  19
# 	 3  /  19
# 	Stopping threshold met -- exiting after 3 iterations
# ...

# %%
proj_v2 = HNNE_V2(hnne_v2=True).fit_transform(data, verbose=True)
# Out:
# Building h-NNE hierarchy using FINCH...
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Mon Oct 13 22:22:11 2025 Building RP forest with 32 trees
# Mon Oct 13 22:22:36 2025 NN descent for 23 iterations
# 	 1  /  23
# 	 2  /  23
# 	 3  /  23
# 	 4  /  23
# 	Stopping threshold met -- exiting after 4 iterations
# Step PyNNDescent done ...
# Level 0: 2573726 clusters
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Mon Oct 13 22:24:15 2025 Building RP forest with 32 trees
# Mon Oct 13 22:24:20 2025 NN descent for 21 iterations
# 	 1  /  21
# 	 2  /  21
# 	 3  /  21
# 	 4  /  21
# 	Stopping threshold met -- exiting after 4 iterations
# Step PyNNDescent done ...
# Level 1: 724582 clusters
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Mon Oct 13 22:24:45 2025 Building RP forest with 32 trees
# Mon Oct 13 22:24:46 2025 NN descent for 19 iterations
# 	 1  /  19
# 	 2  /  19
# 	 3  /  19
# ...

# %%
_, axes = plt.subplots(1, 3, figsize=(20, 5))

N = 100_000
idx = np.random.choice(data.shape[0], size=N, replace=False)

plt.suptitle(f"Dataset: {dataset_name}")
ax = axes[0]
ax.set_title("HNNE")
ax.scatter(*proj[idx].T, s=1, c=labels[idx], cmap=cmap)

ax = axes[1]
ax.set_title("HNNE NEW")
ax.scatter(*proj_new[idx].T, s=1, c=labels[idx], cmap=cmap)

ax = axes[2]
ax.set_title("HNNE V2")
ax.scatter(*proj_v2[idx].T, s=1, c=labels[idx], cmap=cmap)

for ax in axes:
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])

plt.show()

# %%
np.savez(
    PROJ_PATH / f"{dataset_name}.npz", 
    proj=proj, 
    proj_new=proj_new, 
    proj_v2=proj_v2, 
    labels=labels
)

# %% [markdown]
# ### Google News

# %%
dataset_name = "Google News"
data, labels = load_google_news(DATA_PATH)
print(data.shape, labels.shape)
# Out:
# (3000000, 300) (3000000,)

# %%
proj = HNNE_ORIG().fit_transform(data, verbose=True)
# Out:
# Building h-NNE hierarchy using FINCH...
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Mon Oct 13 22:30:08 2025 Building RP forest with 32 trees
# Mon Oct 13 22:30:45 2025 NN descent for 22 iterations
# 	 1  /  22
# 	 2  /  22
# 	 3  /  22
# 	 4  /  22
# 	 5  /  22
# 	Stopping threshold met -- exiting after 5 iterations
# Step PyNNDescent done ...
# Level 0: 299107 clusters
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Mon Oct 13 22:31:13 2025 Building RP forest with 28 trees
# Mon Oct 13 22:31:15 2025 NN descent for 18 iterations
# 	 1  /  18
# 	 2  /  18
# 	 3  /  18
# 	 4  /  18
# 	 5  /  18
# 	Stopping threshold met -- exiting after 5 iterations
# Step PyNNDescent done ...
# Level 1: 28610 clusters
# Level 2: 4459 clusters
# Level 3: 817 clusters
# Level 4: 186 clusters
# Level 5: 42 clusters
# Level 6: 12 clusters
# Level 7: 3 clusters
# Projecting to 2 dimensions...
# [299107, 28610, 4459, 817, 186, 42, 12, 3]
# ...

# %%
proj_new = HNNE_V2(hnne_v2=False).fit_transform(data, verbose=True)
# Out:
# Building h-NNE hierarchy using FINCH...
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Mon Oct 13 22:31:55 2025 Building RP forest with 32 trees
# Mon Oct 13 22:32:31 2025 NN descent for 22 iterations
# 	 1  /  22
# 	 2  /  22
# 	 3  /  22
# 	 4  /  22
# 	 5  /  22
# 	Stopping threshold met -- exiting after 5 iterations
# Step PyNNDescent done ...
# Level 0: 299753 clusters
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Mon Oct 13 22:32:59 2025 Building RP forest with 28 trees
# Mon Oct 13 22:33:01 2025 NN descent for 18 iterations
# 	 1  /  18
# 	 2  /  18
# 	 3  /  18
# 	 4  /  18
# 	 5  /  18
# 	Stopping threshold met -- exiting after 5 iterations
# Step PyNNDescent done ...
# Level 1: 28677 clusters
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Mon Oct 13 22:33:04 2025 Building RP forest with 18 trees
# Mon Oct 13 22:33:04 2025 NN descent for 15 iterations
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	 4  /  15
# ...

# %%
proj_v2 = HNNE_V2(hnne_v2=True).fit_transform(data, verbose=True)
# Out:
# Building h-NNE hierarchy using FINCH...
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Mon Oct 13 22:33:32 2025 Building RP forest with 32 trees
# Mon Oct 13 22:34:10 2025 NN descent for 22 iterations
# 	 1  /  22
# 	 2  /  22
# 	 3  /  22
# 	 4  /  22
# 	 5  /  22
# 	Stopping threshold met -- exiting after 5 iterations
# Step PyNNDescent done ...
# Level 0: 299210 clusters
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Mon Oct 13 22:34:39 2025 Building RP forest with 28 trees
# Mon Oct 13 22:34:41 2025 NN descent for 18 iterations
# 	 1  /  18
# 	 2  /  18
# 	 3  /  18
# 	 4  /  18
# 	 5  /  18
# 	Stopping threshold met -- exiting after 5 iterations
# Step PyNNDescent done ...
# Level 1: 28799 clusters
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Mon Oct 13 22:34:44 2025 Building RP forest with 18 trees
# Mon Oct 13 22:34:44 2025 NN descent for 15 iterations
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	 4  /  15
# ...

# %%
_, axes = plt.subplots(1, 3, figsize=(20, 5))

N = 100_000
idx = np.random.choice(data.shape[0], size=N, replace=False)

plt.suptitle(f"Dataset: {dataset_name}")
ax = axes[0]
ax.set_title("HNNE")
ax.scatter(*proj[idx].T, s=1, c=labels[idx], cmap=cmap)

ax = axes[1]
ax.set_title("HNNE NEW")
ax.scatter(*proj_new[idx].T, s=1, c=labels[idx], cmap=cmap)

ax = axes[2]
ax.set_title("HNNE V2")
ax.scatter(*proj_v2[idx].T, s=1, c=labels[idx], cmap=cmap)

for ax in axes:
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])

plt.show()

# %%
np.savez(
    PROJ_PATH / f"{dataset_name}.npz", 
    proj=proj, 
    proj_new=proj_new, 
    proj_v2=proj_v2, 
    labels=labels
)
